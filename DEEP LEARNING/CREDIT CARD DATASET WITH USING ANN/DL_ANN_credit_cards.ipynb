# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe(include='all')
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
sns.countplot(x='Class',data=df)

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
X = df.iloc[:,:-1]
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.utils import resample

# setting up testing and training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=26)

# concatenate our training data back together
df1 = pd.concat([X_train, y_train], axis=1)

df_majority = df1[df1.Class==0]
df_minority = df1[df1.Class==1]


# Downsample majority class
df_downsampled = resample(df_majority, 
                                 replace=True,    # sample without replacement
                                 n_samples=50000 ,  # to match minority class
                                 random_state = 1234) # reproducible results
# Upsample minority class

df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=5000,    # to match majority class
                                 random_state=1234) # reproducible results
 
# Combine minority class with downsampled majority class
df_sampled = pd.concat([df_downsampled, df_minority_upsampled])
 
# Display new class counts
df_sampled.Class.value_counts()
# Out:
# 0    50000
# 1     5000
# Name: Class, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 5)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train.ravel())
print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# After OverSampling, counts of label '1': 213245
# After OverSampling, counts of label '0': 213245

# %%
X = df_sampled.iloc[:,:-1]
y = df_sampled['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=26)

# %%
df_downsampled.shape    #downsampled for class-0
# Out:
# (50000, 31)

# %%
df_minority_upsampled.shape     #upsampling for class-1
# Out:
# (5000, 31)

# %%
print(X_train.shape, y_train.shape)

print(X_test.shape, y_test.shape)
# Out:
# (41250, 30) (41250,)
# (13750, 30) (13750,)

# %%
#NUMERICAL COLUMNS
X_train_num = X_train.select_dtypes(include=['float64'])

X_train_num.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 259355  159076.0 -0.685124  0.785682  0.719621  0.632179  1.318503  0.862559
# 243768  152063.0 -0.856386  1.494063 -1.211126 -0.581002  0.133039 -0.663738
# 157003  109328.0 -1.349944  1.798738  0.151808 -1.101555  0.853877 -0.558315
# 18864    29829.0  1.218302  0.167588 -0.045777  0.996492  0.504036  0.808004
# 118181   74978.0 -1.425338  1.147738  1.751531  1.789048  0.403304  0.159242
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 259355  1.701765 -0.028863 -0.704537  ...  0.012818  0.117997  0.548160
# 243768  0.040579  1.001176 -0.236832  ... -0.157534 -0.236985 -0.847169
# 157003  1.575189 -0.908233  3.141606  ...  1.097266 -0.873246 -0.759699
# 18864  -0.051778  0.192890  0.075003  ... -0.141210 -0.128368 -0.133676
# 118181  0.458998  0.362297 -1.533746  ... -0.313260 -0.094994 -0.256836
#
# ...

# %%
# scaling the numerical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 259355  1.377150 -0.087709  0.213914  0.411518  0.110178  0.709327  0.679341
# 243768  1.230318 -0.144122  0.531442 -0.186029 -0.483859  0.181250 -0.379291
# 157003  0.335565 -0.306701  0.668010  0.235785 -0.738749  0.502355 -0.306170
# 18864  -1.328925  0.539283 -0.063142  0.174635  0.288565  0.346515  0.641502
# 118181 -0.383630 -0.331536  0.376204  0.730884  0.676642  0.301643  0.191524
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 259355  0.775763 -0.041467 -0.329832  ... -0.028591  0.034252  0.686910
# 243768  0.185084  0.436191 -0.012039  ... -0.237175 -0.246115 -1.059901
# 157003  0.730756 -0.449255  2.283514  ...  1.299240 -0.748636 -0.950396
# 18864   0.152245  0.061366  0.199844  ... -0.217187 -0.160329 -0.166680
# 118181  0.333865  0.139925 -0.893256  ... -0.427851 -0.133969 -0.320864
#
# ...

# %%
#NUMERICAL COLUMNS
X_test_num = X_test.select_dtypes(include=['float64'])

X_test_num.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 80146    58354.0 -1.198052  0.893356  1.039869  0.865633 -0.488713 -0.034762
# 264734  161568.0 -0.719026  0.344877 -0.948010 -1.070632  1.641156 -1.295217
# 76566    56630.0 -2.909382  2.736176 -0.776513  0.813371 -1.522088 -0.381653
# 202179  134205.0  2.136684 -1.037872 -0.405406 -0.831816 -1.045214 -0.216214
# 196508  131543.0  2.037076 -0.141390 -1.252944  0.195539  0.135918 -0.614248
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 80146   0.185643  0.565725 -0.610847  ... -0.382320  0.169436  0.260158
# 264734  1.423351 -0.276288 -0.480930  ... -0.148306  0.270120  0.982746
# 76566  -1.310797  2.104585 -0.992834  ... -0.628241  0.524021  0.589712
# 202179 -1.152572 -0.055539  0.184349  ...  0.093143  0.441435  1.404334
# 196508  0.080873 -0.158223  0.317016  ... -0.182700 -0.264167 -0.680513
#
# ...

# %%
X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num), 
                                    columns = X_test_num.columns, 
                                    index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 80146  -0.731690 -0.256668  0.262179  0.510632  0.224489 -0.095715  0.056964
# 264734  1.429326 -0.098876  0.016326 -0.104597 -0.723608  0.853056 -0.817282
# 76566  -0.767786 -0.820382  1.088210 -0.051521  0.198899 -0.556042 -0.183638
# 202179  0.856420  0.841799 -0.603482  0.063333 -0.606671 -0.343614 -0.068891
# 196508  0.800685  0.808988 -0.201640 -0.198971 -0.103624  0.182533 -0.344965
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 80146   0.236666  0.234261 -0.266173  ... -0.512410  0.074878  0.326361
# 264734  0.676766 -0.156204 -0.177898  ... -0.225875  0.154399  1.230967
# 76566  -0.295433  0.947873 -0.525722  ... -0.813523  0.354932  0.738929
# 202179 -0.239172 -0.053837  0.274141  ...  0.069761  0.289705  1.758753
# 196508  0.199412 -0.101454  0.364285  ... -0.267989 -0.267583 -0.851264
#
# ...

# %%
#Import required libraries 
import keras #library for neural network
import pandas as pd #loading data in table form  
import seaborn as sns #visualisation 
import matplotlib.pyplot as plt #visualisation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import normalize #machine learning algorithm library

# %%
#Neural network module
from keras.models import Sequential 
from keras.layers import Dense,Activation  
from keras.utils import np_utils

# %%
model=Sequential()

model.add(Dense(32,input_dim=30, activation = 'relu'))
#Dropout(0.2)
model.add(Dense(64))
model.add(Dense(128))
model.add(Dense(128))
model.add((Dense(256)))
model.add(Dense(256))
model.add(Dense(128))
model.add(Dense(128))
model.add(Dense(64))

model.add(Dense(1,activation='sigmoid'))


model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_50 (Dense)            (None, 32)                992
#
#  dense_51 (Dense)            (None, 64)                2112
#
#  dense_52 (Dense)            (None, 128)               8320
#
#  dense_53 (Dense)            (None, 128)               16512
#
#  dense_54 (Dense)            (None, 256)               33024
#
#  dense_55 (Dense)            (None, 256)               65792
#
#  dense_56 (Dense)            (None, 128)               32896
#
#  dense_57 (Dense)            (None, 128)               16512
#
#  dense_58 (Dense)            (None, 64)                8256
#
#  dense_59 (Dense)            (None, 1)                 65
#
# ...
# Total params: 184,481
# Trainable params: 184,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,batch_size=20,epochs=10,verbose=77)
# Out:
# Epoch 1/10
# Epoch 2/10
# Epoch 3/10
# Epoch 4/10
# Epoch 5/10
# Epoch 6/10
# Epoch 7/10
# Epoch 8/10
# Epoch 9/10
# Epoch 10/10

# %%
score = model.evaluate(X_test,y_test)
print(score)
# Out:
# 430/430 [==============================] - 1s 2ms/step - loss: 0.1269 - accuracy: 0.9765
# [0.1268911063671112, 0.9765090942382812]

# %%
#BY USING ML ALGORITHMS:

# %%
from sklearn.linear_model import LogisticRegression
regressor= LogisticRegression()
regressor.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
y_test_pred = regressor.predict(X_test)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#         Actual  Predicted
# 80146        0          0
# 264734       0          0
# 76566        0          0
# 202179       0          0
# 196508       0          0

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.9803636363636363

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree_model = DecisionTreeClassifier()
decision_tree_model.fit(X_train, y_train)
y_pred = decision_tree_model.predict(X_test)
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.998109090909091

# %%
decision_tree_model.fit(X_test,y_test)
y_train_pred = decision_tree_model.predict(X_train)
metrics.accuracy_score(y_train,y_train_pred)
# Out:
# 0.9932363636363636
