# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
review = pd.read_csv(r"D:/saikrishna data science/MACHINE TEXT PROJECT/amazon_food_reviews/amazon_food_reviews.csv")

# %%
review
# Out:
#         Unnamed: 0                        0                         1  \
# 0                0  ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1                1  ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2                2  ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3                3  ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4                4  ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
# ...            ...                      ...                       ...
# 568448      568448  ProductId: B001EO7N10\n  UserId: A1F6BHEYB7R6R7\n
# 568449      568449  ProductId: B001EO7N10\n  UserId: A28KG5XORO54AY\n
# 568450      568450  ProductId: B003S1WTCU\n  UserId: A3I8AFVPEE8KI5\n
# 568451      568451  ProductId: B004I613EE\n  UserId: A121AA1GQV751Z\n
# 568452      568452  ProductId: B004I613EE\n   UserId: A3IBEVCTXKNOH\n
#
#                                                      2  \
# 0                            ProfileName: delmartian\n
# ...

# %%
review.rename(columns={"Unnamed: 0":'Id','0':'ProductId','1':'UserId','2':'ProfileName','3':'HelpfulnessNumerator','4':'HelpfulnessDenominator','5':'Score','6':'Time','7':'ReviewSummary','8':'ReviewText'},inplace=True)

# %%
review.head()
# Out:
#    Id                ProductId                    UserId  \
# 0   0  ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1   1  ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2   2  ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3   3  ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4   4  ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
#
#                                       ProfileName       HelpfulnessNumerator  \
# 0                       ProfileName: delmartian\n  HelpfulnessNumerator: 1\n
# 1                           ProfileName: dll pa\n  HelpfulnessNumerator: 0\n
# 2  ProfileName: Natalia Corres "Natalia Corres"\n  HelpfulnessNumerator: 1\n
# 3                             ProfileName: Karl\n  HelpfulnessNumerator: 3\n
# 4    ProfileName: Michael D. Bigham "M. Wassir"\n  HelpfulnessNumerator: 0\n
#
#         HelpfulnessDenominator       Score                Time  \
# 0  HelpfulnessDenominator: 1\n  Score: 5\n  Time: 1303862400\n
# ...

# %%
review.set_index('Id', inplace=True)

# %%
review.head()
# Out:
#                   ProductId                    UserId  \
# Id
# 0   ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1   ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2   ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3   ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4   ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
#
#                                        ProfileName       HelpfulnessNumerator  \
# Id
# 0                        ProfileName: delmartian\n  HelpfulnessNumerator: 1\n
# 1                            ProfileName: dll pa\n  HelpfulnessNumerator: 0\n
# 2   ProfileName: Natalia Corres "Natalia Corres"\n  HelpfulnessNumerator: 1\n
# 3                              ProfileName: Karl\n  HelpfulnessNumerator: 3\n
# 4     ProfileName: Michael D. Bigham "M. Wassir"\n  HelpfulnessNumerator: 0\n
#
#          HelpfulnessDenominator       Score                Time  \
# Id
# 0   HelpfulnessDenominator: 1\n  Score: 5\n  Time: 1303862400\n
# ...

# %%
UserId = []
for i in review['UserId']:
    UserId.append(i.split()[1])

# %%
review['UserId'] = UserId

# %%
review.head()
# Out:
#                   ProductId          UserId  \
# Id
# 0   ProductId: B001E4KFG0\n  A3SGXH7AUHU8GW
# 1   ProductId: B00813GRG4\n  A1D87F6ZCVE5NK
# 2   ProductId: B000LQOCH0\n   ABXLMWJIXXAIN
# 3   ProductId: B000UA0QIQ\n  A395BORC6FGVXV
# 4   ProductId: B006K2ZZ7K\n  A1UQRSCLF8GW1T
#
#                                        ProfileName       HelpfulnessNumerator  \
# Id
# 0                        ProfileName: delmartian\n  HelpfulnessNumerator: 1\n
# 1                            ProfileName: dll pa\n  HelpfulnessNumerator: 0\n
# 2   ProfileName: Natalia Corres "Natalia Corres"\n  HelpfulnessNumerator: 1\n
# 3                              ProfileName: Karl\n  HelpfulnessNumerator: 3\n
# 4     ProfileName: Michael D. Bigham "M. Wassir"\n  HelpfulnessNumerator: 0\n
#
#          HelpfulnessDenominator       Score                Time  \
# Id
# 0   HelpfulnessDenominator: 1\n  Score: 5\n  Time: 1303862400\n
# 1   HelpfulnessDenominator: 0\n  Score: 1\n  Time: 1346976000\n
# ...

# %%
ProductId = []
for i in review['ProductId']:
    ProductId.append(i.split()[1])
    
review['ProductId'] = ProductId

# %%
review.head()
# Out:
#      ProductId          UserId  \
# Id
# 0   B001E4KFG0  A3SGXH7AUHU8GW
# 1   B00813GRG4  A1D87F6ZCVE5NK
# 2   B000LQOCH0   ABXLMWJIXXAIN
# 3   B000UA0QIQ  A395BORC6FGVXV
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                                        ProfileName       HelpfulnessNumerator  \
# Id
# 0                        ProfileName: delmartian\n  HelpfulnessNumerator: 1\n
# 1                            ProfileName: dll pa\n  HelpfulnessNumerator: 0\n
# 2   ProfileName: Natalia Corres "Natalia Corres"\n  HelpfulnessNumerator: 1\n
# 3                              ProfileName: Karl\n  HelpfulnessNumerator: 3\n
# 4     ProfileName: Michael D. Bigham "M. Wassir"\n  HelpfulnessNumerator: 0\n
#
#          HelpfulnessDenominator       Score                Time  \
# Id
# 0   HelpfulnessDenominator: 1\n  Score: 5\n  Time: 1303862400\n
# 1   HelpfulnessDenominator: 0\n  Score: 1\n  Time: 1346976000\n
# 2   HelpfulnessDenominator: 1\n  Score: 4\n  Time: 1219017600\n
# ...

# %%
HelpfulnessNumerator = []
for i in review['HelpfulnessNumerator']:
    HelpfulnessNumerator.append(i.split()[1])
    
review['HelpfulnessNumerator'] = HelpfulnessNumerator

# %%
review.head()
# Out:
#      ProductId          UserId  \
# Id
# 0   B001E4KFG0  A3SGXH7AUHU8GW
# 1   B00813GRG4  A1D87F6ZCVE5NK
# 2   B000LQOCH0   ABXLMWJIXXAIN
# 3   B000UA0QIQ  A395BORC6FGVXV
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                                        ProfileName HelpfulnessNumerator  \
# Id
# 0                        ProfileName: delmartian\n                    1
# 1                            ProfileName: dll pa\n                    0
# 2   ProfileName: Natalia Corres "Natalia Corres"\n                    1
# 3                              ProfileName: Karl\n                    3
# 4     ProfileName: Michael D. Bigham "M. Wassir"\n                    0
#
#          HelpfulnessDenominator       Score                Time  \
# Id
# 0   HelpfulnessDenominator: 1\n  Score: 5\n  Time: 1303862400\n
# 1   HelpfulnessDenominator: 0\n  Score: 1\n  Time: 1346976000\n
# 2   HelpfulnessDenominator: 1\n  Score: 4\n  Time: 1219017600\n
# 3   HelpfulnessDenominator: 3\n  Score: 2\n  Time: 1307923200\n
# ...

# %%
HelpfulnessDenominator = []
for i in review['HelpfulnessDenominator']:
    HelpfulnessDenominator.append(i.split()[1])
    
review['HelpfulnessDenominator'] = HelpfulnessDenominator

# %%
Score = []
for i in review['Score']:
    Score.append(i.split()[1])
    
review['Score'] = Score

# %%
Time = []
for i in review['Time']:
    Time.append(i.split()[1])
    
review['Time'] = Time

# %%
review.head()
# Out:
#      ProductId          UserId  \
# Id
# 0   B001E4KFG0  A3SGXH7AUHU8GW
# 1   B00813GRG4  A1D87F6ZCVE5NK
# 2   B000LQOCH0   ABXLMWJIXXAIN
# 3   B000UA0QIQ  A395BORC6FGVXV
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                                        ProfileName HelpfulnessNumerator  \
# Id
# 0                        ProfileName: delmartian\n                    1
# 1                            ProfileName: dll pa\n                    0
# 2   ProfileName: Natalia Corres "Natalia Corres"\n                    1
# 3                              ProfileName: Karl\n                    3
# 4     ProfileName: Michael D. Bigham "M. Wassir"\n                    0
#
#    HelpfulnessDenominator Score        Time  \
# Id
# 0                       1     5  1303862400
# 1                       0     1  1346976000
# 2                       1     4  1219017600
# 3                       3     2  1307923200
# 4                       0     5  1350777600
#
#                              ReviewSummary  \
# ...

# %%
review['ReviewText'] = review['ReviewText'].apply(lambda x:x.replace('ReviewText:',""))

# %%
review.head()
# Out:
#      ProductId          UserId  \
# Id
# 0   B001E4KFG0  A3SGXH7AUHU8GW
# 1   B00813GRG4  A1D87F6ZCVE5NK
# 2   B000LQOCH0   ABXLMWJIXXAIN
# 3   B000UA0QIQ  A395BORC6FGVXV
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                                        ProfileName HelpfulnessNumerator  \
# Id
# 0                        ProfileName: delmartian\n                    1
# 1                            ProfileName: dll pa\n                    0
# 2   ProfileName: Natalia Corres "Natalia Corres"\n                    1
# 3                              ProfileName: Karl\n                    3
# 4     ProfileName: Michael D. Bigham "M. Wassir"\n                    0
#
#    HelpfulnessDenominator Score        Time  \
# Id
# 0                       1     5  1303862400
# 1                       0     1  1346976000
# 2                       1     4  1219017600
# 3                       3     2  1307923200
# 4                       0     5  1350777600
#
#                              ReviewSummary  \
# ...

# %%
review['ProfileName'] = review['ProfileName'].apply(lambda x:x.replace('ProfileName:',""))
review['ProfileName'] = review['ProfileName'].apply(lambda x:x.replace('\n',""))

# %%
review.head()
# Out:
#      ProductId          UserId                       ProfileName  \
# Id
# 0   B001E4KFG0  A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4  A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0   ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ  A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator HelpfulnessDenominator Score        Time  \
# Id
# 0                     1                      1     5  1303862400
# 1                     0                      0     1  1346976000
# 2                     1                      1     4  1219017600
# 3                     3                      3     2  1307923200
# 4                     0                      0     5  1350777600
#
#                              ReviewSummary  \
# Id
# 0   ReviewSummary: Good Quality Dog Food\n
# 1       ReviewSummary: Not as Advertised\n
# ...

# %%
review['ReviewSummary'] = review['ReviewSummary'].apply(lambda x:x.replace('ReviewSummary:',""))
review['ReviewSummary'] = review['ReviewSummary'].apply(lambda x:x.replace('\n',""))

# %%
review.head()
# Out:
#      ProductId          UserId                       ProfileName  \
# Id
# 0   B001E4KFG0  A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4  A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0   ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ  A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator HelpfulnessDenominator Score        Time  \
# Id
# 0                     1                      1     5  1303862400
# 1                     0                      0     1  1346976000
# 2                     1                      1     4  1219017600
# 3                     3                      3     2  1307923200
# 4                     0                      0     5  1350777600
#
#              ReviewSummary                                         ReviewText
# Id
# 0    Good Quality Dog Food   I have bought several of the Vitality canned ...
# ...

# %%
review.to_csv("review.csv",index=False)

# %%
review.shape
# Out:
# (568453, 9)

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 568453 entries, 0 to 568452
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568453 non-null  object
#  1   UserId                  568453 non-null  object
#  2   ProfileName             568453 non-null  object
#  3   HelpfulnessNumerator    568453 non-null  object
#  4   HelpfulnessDenominator  568453 non-null  object
#  5   Score                   568453 non-null  object
#  6   Time                    568453 non-null  object
#  7   ReviewSummary           568453 non-null  object
#  8   ReviewText              568453 non-null  object
# dtypes: object(9)
# memory usage: 43.4+ MB

# %%
review['HelpfulnessNumerator'] = review['HelpfulnessNumerator'].astype(str).astype('int64')

# %%
review['HelpfulnessDenominator'] = review['HelpfulnessDenominator'].astype(str).astype('int64')

# %%
review['Score'] = review['Score'].astype(str).astype('int64')

# %%
amzon_review = review.drop_duplicates()

# %%
amzon_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 568172 entries, 0 to 568452
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568172 non-null  object
#  1   UserId                  568172 non-null  object
#  2   ProfileName             568172 non-null  object
#  3   HelpfulnessNumerator    568172 non-null  int64
#  4   HelpfulnessDenominator  568172 non-null  int64
#  5   Score                   568172 non-null  int64
#  6   Time                    568172 non-null  object
#  7   ReviewSummary           568172 non-null  object
#  8   ReviewText              568172 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 43.3+ MB

# %%
sentiment = []
for i in amzon_review['Score']:
    if i > 3:
        sentiment.append('positive')
    elif i < 3:
        sentiment.append('negative')
    else:
        sentiment.append('not')
amzon_review['sentiment'] = sentiment

# %%
amzon_review.head()
# Out:
#      ProductId          UserId                       ProfileName  \
# Id
# 0   B001E4KFG0  A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4  A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0   ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ  A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# Id
# 0                      1                       1      5  1303862400
# 1                      0                       0      1  1346976000
# 2                      1                       1      4  1219017600
# 3                      3                       3      2  1307923200
# 4                      0                       0      5  1350777600
#
#              ReviewSummary                                         ReviewText  \
# Id
# ...

# %%
amzon_review['Helpfulness'] = amzon_review['HelpfulnessNumerator']/amzon_review['HelpfulnessDenominator']

# %%
usefulness = []
for i in amzon_review['Helpfulness']:
    if i > 0.75:
        usefulness.append(">75%")
    elif i < 0.25:
        usefulness.append("<25%")
    elif i >= 0.25 and i <= 0.75:
        usefulness.append("25-75%")
    else:
        usefulness.append("useless")
amzon_review['Helpfulness']  = usefulness

# %%
word_count = []
for i in amzon_review['ReviewText']:
    word_count.append(len(i.split()))
amzon_review['word_count'] = word_count

# %%
amzon_review.head()
# Out:
#      ProductId          UserId                       ProfileName  \
# Id
# 0   B001E4KFG0  A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4  A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0   ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ  A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# Id
# 0                      1                       1      5  1303862400
# 1                      0                       0      1  1346976000
# 2                      1                       1      4  1219017600
# 3                      3                       3      2  1307923200
# 4                      0                       0      5  1350777600
#
#              ReviewSummary                                         ReviewText  \
# Id
# ...

# %%
pos = amzon_review[amzon_review['sentiment']=='positive']

# %%
pos
# Out:
#          ProductId          UserId                       ProfileName  \
# Id
# 0       B001E4KFG0  A3SGXH7AUHU8GW                        delmartian
# 2       B000LQOCH0   ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 4       B006K2ZZ7K  A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
# 5       B006K2ZZ7K   ADT0SRK1MGOEU                    Twoapennything
# 6       B006K2ZZ7K  A1SP2KVKFXXRU1                 David C. Sullivan
# ...            ...             ...                               ...
# 568447  B001EO7N10   APWCOAVILK94B        Real Named Person "wowzee"
# 568448  B001EO7N10  A1F6BHEYB7R6R7                      James Braley
# 568449  B001EO7N10  A28KG5XORO54AY                  Lettie D. Carter
# 568451  B004I613EE  A121AA1GQV751Z                     pksd "pk_007"
# 568452  B004I613EE   A3IBEVCTXKNOH           Kathy A. Welch "katwel"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# Id
# ...

# %%
neg = amzon_review[amzon_review['sentiment']=='negative']
neg
# Out:
#          ProductId          UserId       ProfileName  HelpfulnessNumerator  \
# Id
# 1       B00813GRG4  A1D87F6ZCVE5NK            dll pa                     0
# 3       B000UA0QIQ  A395BORC6FGVXV              Karl                     3
# 12      B0009XLVG0   A327PCT23YH90                LT                     1
# 16      B001GVISJM  A3KLWF6WQ5BNYO    Erica Neathery                     0
# 26      B001GVISJM  A3RXAU2N8KV45G            lady21                     0
# ...            ...             ...               ...                   ...
# 568433  B003XUL27E  A1JUG9WCN1A52Z        maudlin666                     0
# 568434  B003XUL27E   ABGQPE97ZVYJ3   Katherine Kelly                     0
# 568435  B003XUL27E  A2PSB4WQHH46HN          carlyowu                     0
# 568446  B001EO7N10  A2P9W8T7NTLG2Z              Andy                     0
# 568450  B003S1WTCU  A3I8AFVPEE8KI5         R. Sawyer                     0
#
#         HelpfulnessDenominator  Score        Time  \
# Id
# ...

# %% [markdown]
# ### DISTRIBUTION OF RATING

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Score',data=amzon_review)
plt.title(' Score(Ratings)')
plt.show()

# %% [markdown]
# - POSTIVE REVIEWS ARE MORE.
# - 5 SCORES ARE MORE.

# %% [markdown]
# ### Popular words in Positive Reviews (4-5 Rating)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
comment_words = ''
stopwords = set(STOPWORDS)


for val in pos['ReviewSummary']:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    comment_words += " ".join(tokens)+" "
     
    
wordcloud = WordCloud(width = 600, height = 600,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)    
    
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# ### Popular words in Negative Reviews (1-2 Rating)

# %%
comment_words = ''
stopwords = set(STOPWORDS)

for val in neg['ReviewSummary']:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    comment_words += " ".join(tokens)+" "
    
wordcloud = WordCloud(width = 600, height = 600,
                background_color ='black',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)    
    
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# ### Distribution of Helpfulness

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Helpfulness',data=amzon_review,order=['useless','>75%','25-75%','<25%'],palette="rocket_r")
plt.title('Distribution of Helpfulness')
plt.show()

# %% [markdown]
# - USELESS ARE MORE IN DISTRIBUTION OF HELPFULNESS.
# - 75> % ARE MORE COMPARED TO 25-75% AND <25%.

# %% [markdown]
# ### Rating Affect Helpfulness

# %%
amzon_review['Helpfulness'].value_counts()
# Out:
# useless    269849
# >75%       202798
# 25-75%      57269
# <25%        38256
# Name: Helpfulness, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Score',data=amzon_review,hue='Helpfulness',hue_order=['>75%','25-75%','<25%'],order=[5,4,3,2,1],palette="rocket_r")
plt.xticks(rotation=90,fontsize=10)
plt.title('COMPARING THE SCORE WITH USEFULNESS')
plt.show()

# %% [markdown]
# - 5 SCORE RATING ARE HELPFUL IN >75% HELPFULNESS.

# %% [markdown]
# ### word count vary by rating

# %%
rating = amzon_review[amzon_review['Score']== 1].word_count.median()

# %%
rating
# Out:
# 62.0

# %%
rating = amzon_review[amzon_review['Score']== 2].word_count.median()

# %%
rating
# Out:
# 67.0

# %%
rating = amzon_review[amzon_review['Score']== 3].word_count.median()

# %%
rating
# Out:
# 70.0

# %%
rating = amzon_review[amzon_review['Score']== 4].word_count.median()
rating
# Out:
# 65.0

# %%
rating = amzon_review[amzon_review['Score']== 5].word_count.median()
rating
# Out:
# 52.0

# %% [markdown]
# - FOR 3 SCORE RATING WORD_COUNT MEDIAN IS LARGER 70
# - FOR 5 SCORE RATING WORD_COUNT MEDIAN IS SMALL 52.
# - FOR 5 SCORE RAING REVIEWS TEXT IS LESS.

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='Score',y='word_count',data=amzon_review,showfliers=False)
plt.xticks(rotation=90,fontsize=10)
plt.title('COMPARING THE SCORE WITH USEFULNESS')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='Helpfulness',y='word_count',data=amzon_review,order=['>75%','<25%'])
plt.ylim(-20, 500)
plt.xticks(rotation=90,fontsize=10)
plt.title('COMPARING THE SCORE WITH USEFULNESS')
plt.show()

# %% [markdown]
# ### CONCULSION

# %% [markdown]
# - POSTIVE COMMENTS ARE MORE.
# - 5 SCORE RATINGS ARE MORE HELPFUL.
# - 5 SCORE RATINGS WORD_COUNT IS LESS.
# - USELESS ARE MORE IN DISTRIBUTION OF HELPFULNESS.
